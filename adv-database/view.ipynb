# %%
import json
import os
import sys
import time
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
plt.style.use('default')
plt.rc('text', usetex=True)
plt.rc('font', family='sans-serif')
plt.rc('font', size=18)
plt.rc('axes', titlesize=18)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('lines', markersize=10)

# %%
df = pd.read_csv('newdb.csv')

# %%
df.head()
# Out:
#                                nom_de_l_etablissment  ips_voie_pro  \
# 0  LYCEE PROFESSIONNEL LE CHAMP DE CLAYE LYCEE DE...          87.4
# 1             LYCEE GENERAL ET TECHNOLOGIQUE GALILEE           NaN
# 2            LYCEE PROFESSIONNEL PRIVE LES SINOPLIES         114.2
# 3  LYCEE GENERAL ET TECHNOLOGIQUE PIERRE MENDES F...           NaN
# 4                LYCEE POLYVALENT MARTIN LUTHER KING           NaN
#
#   type_de_lycee             secteur       uai  ips_ensemble_gt_pro  \
# 0            LP              public  0771995A                 87.4
# 1          LEGT              public  0772127U                115.6
# 2            LP  privé sous contrat  0772151V                114.2
# 3          LEGT              public  0772188K                 99.4
# 4          LEGT              public  0772292Y                121.3
#
#    code_du_departement rentree_scolaire  code_insee_de_la_commune academie  \
# 0                 77.0        2018-2019                   77118.0  CRETEIL
# 1                 77.0        2018-2019                   77122.0  CRETEIL
# 2                 77.0        2018-2019                   77390.0  CRETEIL
# 3                 77.0        2018-2019                   77445.0  CRETEIL
# 4                 77.0        2018-2019                   77058.0  CRETEIL
#
#       departement    nom_de_la_commune  ips_voie_gt  \
# 0  SEINE-ET-MARNE        CLAYE SOUILLY          NaN
# 1  SEINE-ET-MARNE       COMBS LA VILLE        115.6
# 2  SEINE-ET-MARNE       ROISSY EN BRIE          NaN
# 3  SEINE-ET-MARNE    SAVIGNY LE TEMPLE         99.4
# 4  SEINE-ET-MARNE  BUSSY SAINT GEORGES        121.3
#
#    ecart_type_de_l_ips_voie_pro  ecart_type_de_l_ips_voie_gt
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN

# %%
fig, ax = plt.subplots(figsize=(10, 5))
msno.matrix(df, ax=ax, sparkline=False, fontsize=12)
plt.show()
