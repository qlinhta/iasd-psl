# %%
import keras
import numpy as np
import tensorflow as tf

# %%
path = keras.utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.legacy.RMSprop(learning_rate=0.01))

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)

    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 44s 27ms/step - loss: 1.9663
# --- Generating with seed: " both of which the country in question has
# now a classic rep"
# ------ temperature: 0.2
#  both of which the country in question has
# now a classic repare of the constional to the science of the can the sense of the can the conterned the mankind and the sense of the content of the can the can they whole of the can they which the content of the content of the can the sense of the can the conders of the can the content of the came and the can the sense of the can the great of the can the can the can the condition of the constion of the content and------ temperature: 0.5
# can the can the condition of the constion of the content and longer they would his serving the condernant they to the make
# the every condise and persance be the facult, and really the nature and vermant shart to the great in the present companity they of in the disposting they in ad the present that which which shaves and cain the spience of the beade for every defucts of the for the conder and that has all the been the one one one the caure and most which------ temperature: 1.0
# at has all the been the one one one the caure and most which one doubts ourstelfm-his dame is io reconrup-in that which to coritions ward) to ableable is
# to therefure, as a "consciougor--as the parcal vience, there alpresions "prifttanish so togarinagi) is insuch the schom upondiate of the gheering or of that them ent es mores be it sour now anrepare-oubtuar ow conmines.  hare mearroneen its out ounder whure as contence, add
# that the find
# ruspos, constinge------ temperature: 1.2
# under whure as contence, add
# that the find
# ruspos, constinge herved, hritt who werr and somely juxge of artemonne
# haures of consm"dally goratury
# my muqually beet look being of for earined in
# the syuphtz. fat,y--why impony noifehem of freet
#
# theainkes, be
# mad, new conturains,
# say--1er withing, this "pair velledse with is bilewhreaie tomt ley one firmineverts
# withioue they we have mal-yeardes the siclly in upon it--as owerjout.
# "ald :ier comeas, in evolert:
# epoch 2
# 1565/1565 [==============================] - 40s 25ms/step - loss: 1.6154
# --- Generating with seed: "same part, finally ceases to be a hypocrite; as
# in the case "
# ------ temperature: 0.2
# same part, finally ceases to be a hypocrite; as
# in the case to the spirit, the conception of the spirit and specient of the spirit and spirits and many interpretion of the spirit and many the spirit of the conception of the spirits and consequently and which is and spirit and spirit of the spirit and spirit of the conception of the indecistect of the spirit and indespect and the spirit and spicious and indeed the priscious and destray to the conception of ------ temperature: 0.5
# s and indeed the priscious and destray to the conception of the hears spirits of interest of one conception of to undeed the have of the belief of his means indeed and spicions of events all the comne, the geneutions in the fact indeal of self-spirit at the spiritual world now readfulation
# his of angeroums to the indeciveled therebading power, which the spicious, or individual and intendectly and feelings been therefore and "specient of the live indecality------ temperature: 1.0
# feelings been therefore and "specient of the live indecality to more anti!
# for the mood, christian hopouaded ruledly and one may suppealshens and moun, a dures. thus inrepulation is its disconfect of one must powled, i purtue live,
# it was understom of the goes of plect a accest, the gedation from the
# discurratly modenctionally swoll some incem: s.
#
# raalgitiony heriocing as onie
# humantoly suffering no
# power,  gond incerce2ld, and from indecoped and blunded ------ temperature: 1.2
#  no
# power,  gond incerce2ld, and from indecoped and blunded adsamed.
#
# fully may trymmatists of dignaity ised, all oursith
# in developine subor"tard, the hacfrent.
#
# 1hy idea must outjurlial bedst, bus becumeing to pialiti namuns in an?--liche tomes a
# nowuly, inipate yound but, ximattule? cultued from metare). to clay, he confeesions and arise
# hiddonary vatueelt i men relablymated ragarding--a nois, cail. furthws much the knowledge where learny if who
#  ac staepoch 3
# 1565/1565 [==============================] - 40s 26ms/step - loss: 1.5259
# --- Generating with seed: "
# create values). it may be looked upon as the result of an e"
# ------ temperature: 0.2
#
# create values). it may be looked upon as the result of an expressible of the recertion of the spirit of the soul the present and the true species of the spirit of the spirit of the sense of the sense of the spirit of the soul in the spirit of the spirit of the sense of the spirit of the superstice of the true and the species of the precisely and the species of the spirit of the spirit of the sense of the superfician of the sense of the spirit of the preci------ temperature: 0.5
# e of the superfician of the sense of the spirit of the precises to a most with the fait of the spirit is the world the our extransus all in the very rangerous interlues and with the many for the free spirit of the precersion of the sense of the truth which a soul, a been the should the sport of the christian and that the sempated our has could not fore of the regarde of the former slave, that is the delications of the problem of the grade of the compution ------ temperature: 1.0
# he delications of the problem of the grade of the compution in altergicau ankask of leasner and endarys therever which encernoud in the had uningerably fais of really
# formgnis of the had account how eaking propens of her poification and his ows." the
# self-of our
# from many assentialless a stapes and justiceful of obrality." is alsopentice be it seems to the reass of he preem, inte,tomer, entmucal refunges whether those because of them wishen
# emother fartfic------ temperature: 1.2
# efunges whether those because of them wishen
# emother fartficie as
# we seem-that the delent christiand in "wistpluctius acker" bad artistically mal, thee he greatoming in the indelicants put gene. with there at alsomethir, neuloppie of ittilfarly potink a sure relike ond? will feattesur
# policiate necessarismen,-tootremonoryhasmed, "chilally but ho cuny
# ideaten; in last its a same bounder upon it wearicy muvhous-equers--of the tempond and his
# indotence thest epoch 4
# 1565/1565 [==============================] - 40s 25ms/step - loss: 1.4813
# --- Generating with seed: "eart and head the potent methods of
# truth, one has yet becom"
# ------ temperature: 0.2
# eart and head the potent methods of
# truth, one has yet become and the sense of the sense of the soul and the spiritual and the sufferers and soul and the senses the subject of the subject of the sense of the soul and his had the sense of the sense of the same the contemplation of the soul of the supposity of the soul has a power of the present in the strong and the continue of the sense of the sense of the senses the sense of the sense of the present and t------ temperature: 0.5
# se of the senses the sense of the sense of the present and there is an assument of the father for the demons of the subject of the contection of the disconding the self-destression and had the great for the senses and not be not merely as also of the sensation of the faster in the delight, and the philosophy of the impredised here, and their profest the time of the satisfaces that the fame and the contempt to persons that which the spance of the superstiti------ temperature: 1.0
#  contempt to persons that which the spance of the superstitious which is much, whothing interpreted, darmed about to the lose to has were at himselfingsible to regirnes, and there isongwant and
# hereditarishes opinions it world at, to
# deed, the will. succeridently and must expere lowe a looking unscounds, to larestignantint to prehides so that one asouring, though be a woll
# anoughned standard.--prehary only good! help. the barth to
# do suncerng,
# and we sest
# ------ temperature: 1.2
# hary only good! help. the barth to
# do suncerng,
# and we sest
# unquisted in sgerion
# well even self-ecterits-prefutne theby s(muct or afford.
#
# 1alin own example which to thatepate and dygreaches.=--is the lighton,
# shirth them cutid.y, to hatperomic fain ynemoinis, i should norius an go that a pail noth, that where to both and itself we getfor it noemded!
#
#
# 1ju nothe ourgened in which i joyings of
# knows
# nowadayslolace under pases uguak no way1. ever espessicehaepoch 5
# 1565/1565 [==============================] - 38s 25ms/step - loss: 1.4521
# --- Generating with seed: "men. he must be content with
# such a free, fearless soaring a"
# ------ temperature: 0.2
# men. he must be content with
# such a free, fearless soaring and souls the superiorities of the subject of the subject of the same in the subject of the destrain than the instinct of the souls and the most as the soul, the present in the subject of the same has to be the subject of the strength of the same than the bound and the most as the subject of the means of the same and the successional and the great the strong the most as the strong the most man who ------ temperature: 0.5
# he great the strong the most as the strong the most man who was to the fact of enound, a being of all in the standing tentant its lose among something and the one must be the still least to doffulness and consistant understand the succification of the present and great interpretation. there is the same growledge for the most of ential an entather to the influence of the more with one of the had to made of the degree the sultiness for the discovered of the ------ temperature: 1.0
#  made of the degree the sultiness for the discovered of the art i world sighil, but is "standistic from its beens offer tetrabilitioned--the al ideals, the sensitin
# also of be are cnasmricadness." in the surple, has he being ontise to lood,"--what is the timagenesshess all learns but personal music, from
# pessiatic moghonismated self-sikel into em"thnoushingly much and in be now, of makes: be one moment
# covelosity spreptiness--and he noots, indeed, thy roy ------ temperature: 1.2
# oment
# covelosity spreptiness--and he noots, indeed, thy roy a of but
# my"
# dood,"
# persion is he yet funtively, those tenionence, in the - m obettur,wings toge sautnedishibment of his aumuriatib mankind eadibying ofccasice will,
# creating the emen than this imbul birnsled obscribitian beferre. a harn, lefeinaglg analy merpareness by a last to extruacis an iltykory until scienceke muse something whom wild
# thel. beto mealeties whod made, equal ctlacts to a ren; epoch 6
# 1565/1565 [==============================] - 41s 26ms/step - loss: 1.4298
# --- Generating with seed: "ve to
# be evoked in his mind, that the degree of distinctness"
# ------ temperature: 0.2
# ve to
# be evoked in his mind, that the degree of distinctness of the such a distinguish the present of the far the same strange of the far the man is the spirit and the art of the endure of the any one and the contrays that the sense of the sense of the same and the sense of the endure and all the far the same and the faith in the same and the same and the false and the sense of the far and the strange and interright of the fact of the strange of the same t------ temperature: 0.5
# ange and interright of the fact of the strange of the same that metaphysical the earth and dispated the same most in the day all passion of the act in the far to be their respect there is not perapten and most contradain the first the unselection of the have to be as the first which as a single and inexistence whether the serve and the acts of the ascent and philosophers that a power and the feelings of the moral even being all the spirit of the prompence ------ temperature: 1.0
# ngs of the moral even being all the spirit of the prompence to
# the most
# known onesion to repleacual.
#
#
# 1 ser--that means of qually
# does ne
# recluse's in psilitys, therevin.--with and one should effected metapsuence contincted form, or that
# is man. the
# place the that, so name--another acquire foble."
# ; the gensitur and lose to chethreuca datyfulnted and still, themselves in its decosevessely,
# artpoud: therefore, hard! it is
# of a visityrabilisted be for they ------ temperature: 1.2
# d: therefore, hard! it is
# of a visityrabilisted be for they avoutore for extend currectifely
# spirit aringhiot cerseamet in succesop
# symptatination att ge
# or were bring to because be spirit aed beflature depth or volestrigh yes--extendness unconditioned--psychises.
# wouldly.
# "perhapltecal perceive."
# that at an
# case in
#  and
# nom, when pightene have si"-watrage look as once
# saints the lo-g; which
# enlid oooristic ins
# gladur., they
# we hal natureantly untereally iepoch 7
# 1565/1565 [==============================] - 40s 26ms/step - loss: 1.4137
# --- Generating with seed: " and in earth" is,
# apparently (to repeat it once more), that"
# ------ temperature: 0.2
#  and in earth" is,
# apparently (to repeat it once more), that the spirit the philosophers and powerful and so the strange of the sense of the self-destruction, as a more been all the such a soul as the spirit of the conscience the spirit and soul and deeper and spirit and destruction of the sense of the sense of the self-conscience and believe the religious soul and all the responsibion of the soul of the order to a soul and the strange the same the sense o------ temperature: 0.5
#  of the order to a soul and the strange the same the sense of the conscience the spirit and the responsibitial for the conducts and delight the strong powerful consideration of life all which every mind the conducts the such a strict to proban and the self-itself the prejudice and conflinate the surpicted to german indementally the infer and also the soul of a be for the experiences, the instinct itself is not the philosophers of still in the prehapation o------ temperature: 1.0
# itself is not the philosophers of still in the prehapation of good exurafy one of the
# ywhere the conscience taken notsility.--but
# (it speciouscr-will be author
# livedor
# does use will proveres the or enventing hands beferneness, in nevertheers things through the
# usal god. they, as it goodor, the shoetnignsim through knowing; have his will no poly
# something "the enough in its attay, howeked and disforderg
# of which moralifical powerful
# inventing-so, brotormin------ temperature: 1.2
# rderg
# of which moralifical powerful
#
# inventing-so, brotorminly ut artas and very firm gowner hordky, had everything ratike it fars themgulve to deferation as the
# pathenan and
# ourselves: but there is avoloug read-lature, disgumos us.
#      know do on europuse philosopher. so for the world addrriblen
# omthins" and present already pever alyocy ie surciative:
# whlperly mistaible vivt thistedmonable the scheis. a t reles as as such matte withon generat but responsepoch 8
# 1565/1565 [==============================] - 41s 26ms/step - loss: 1.3999
# --- Generating with seed: "re is
# also the fact that he demands from himself a verdict, "
# ------ temperature: 0.2
# re is
# also the fact that he demands from himself a verdict, and and the same strange of all the same and so that the same and the consequence of the same in the sense of the same of the sense of the same and something of the sense of the same and all the same the same for the sense of the same strict strength of an action of the sense of a strictical and constantly and something of the intermost the german man of the constralical for the once of the same t------ temperature: 0.5
# he german man of the constralical for the once of the same the way of a deep the something and not and constant from such as one is the destrust and above an ascence of the great species of all imperted the sense. is not development of the believe is a rested as they are must and the are the well
# "sensitive, the expressions and actions of mankind in a conditions, and of the have freedom, in all any part of music and for everything and account and every man------ temperature: 1.0
# y part of music and for everything and account and every man attascence" of tical critions, to his dough and intellectios, and way of , garning from that we swill.
# 2an(s of imbened a have,
# everything snothous. but le gery humanity sain to such all bell, believe of the world is nature" which the (an artist, as we have its self feelingsfulswarted that every. looks, of accounds and disposities, falce--for at history spirit he have worlg ever ideas, on vener ------ temperature: 1.2
# e--for at history spirit he have worlg ever ideas, on vener pessible is
# ly the look a sgest the
# blonop and histolimane, is.ecalad, and ple? wondur, slont anvead. to the ininy-isent and pofuatious for ether, throughtailsis want e
# "nature, with thatry or class-, regradity; but st is also
# dough met uncovere-thereropon slands have generalsomed to the fter same obewinness, one should does of the gree bric,
# of curre
# as is
# ey there and praege of metaphysical
# notiepoch 9
# 1565/1565 [==============================] - 41s 26ms/step - loss: 1.3881
# --- Generating with seed: "r the fabric of society seems on the
# whole established and s"
# ------ temperature: 0.2
# r the fabric of society seems on the
# whole established and something of the same and something of the sense of the same and something that the sense of the same and subject and the sense of the same the same the same and the sense of the supposition of the sense of the profoundly and any any something of the sense of the same and something with the same and the sense of the same to the same and soul and soul and acts of the sense of the sense of the sense ------ temperature: 0.5
# ul and soul and acts of the sense of the sense of the sense and actlant
# better false and of the present and love of an endure, and to instance of the soul of the superety, there is their mind the present it is the sense of the seems the same things and acts and as the be instance of shame because the general and a
# disciation or an a men which we are with the basis beautiful and still and
# any one has of them to say not the subject and acts and nothing stron------ temperature: 1.0
# as of them to say not the subject and acts and nothing strongth
# and slaverest sawart, or disclose or "one have put is the same instance,
# on healthularis of the soul however, belief.
#
# ullekness on the vortains mans: -though ageasty
# ma's exertitation of every natural, unaboveten tribed, anything with theortiticiesm, hence a nature the brue to where we degenerate o
# nemoss taster darfortes his tocrance of order to said or on
# itself soeved
# eads of affolt today,------ temperature: 1.2
# e of order to said or on
# itself soeved
# eads of affolt today, and diskest by the labor ashives sceenis of the opposianrs, easiemy  swhachentless syloricatis an obline sick.
#
#
# 12
#
# =some
# devired,
# and the perior work
# of misunders: we devidurititn to a nearced turmicusitihm? in flies-bias
# until cases of doing
# art to an what gentles in every causatical "victors; andorivadator,
# inlitting by themly to
# dnasic enocked
# to -himself to le gartpissic
# "seed is act with aepoch 10
# 1565/1565 [==============================] - 38s 25ms/step - loss: 1.3803
# --- Generating with seed: "and free it
# from the half-christian, half-german narrowness "
# ------ temperature: 0.2
# and free it
# from the half-christian, half-german narrowness of the sense of the fact the same to the sense of the presential of the first and belief to the contrading of the same and for the fathitufication of the same and master of the same and man and something with the struggle of the fathituful to the same of the same something with the same for the sense of the same with the sense of the suffering of the same for the armine of the same of the same in ------ temperature: 0.5
# ering of the same for the armine of the same of the same in sureby of morality and god of the most should through and the fundamental and slouldness of respecting and sympathy of still and for a new individual and like to concerned and possible to many to be something which we may be
# the latter and the presential and endure, is to reading in the form of the armined of such an extend to the fatter of his last in the sustare, if not to be for even the enough------ temperature: 1.0
# of his last in the sustare, if not to be for even the enough to regratest
# undorminating virtueness of
# alse and both point of a ttro chrawasts and forgetter also--to every idrable logic out in life for good
# to inbativent in that plenimster now dapinity,
# as goehts of man or a for the like strenth- other believeds a
# terce of be advance too, we even t o
# loke only to this by a more correctial cast, his haxtopti-ble its. undinededation with
# but
# "could expressien------ temperature: 1.2
#  haxtopti-ble its. undinededation with
# but
# "could expressienting a new pashon-formsion of sympathy of dimini wordr!
#
# reads:
# ; a wholence,
# in
# the narak mag-ivolutio  on
# typhryse, of pposity.
#
# -dormous forgifts arises
# may be dangeroul,
# ass, does stipponess.
# to a telf-wrives aivench waspacuhatings, regard and cannot pe sowardness, and
# forepersons: without syl-advoced.
#
#
#
# 14be
# she to cals from the other
# ct; alon")er, who
# dign
# preachem and religious. supposseleepoch 11
# 1565/1565 [==============================] - 38s 25ms/step - loss: 1.3726
# --- Generating with seed: "sification of
# benefits in accordance with which conduct is d"
# ------ temperature: 0.2
# sification of
# benefits in accordance with which conduct is disposition of the spirit and the sense of the soul and even the spirit of the spirit which is always the same the some in the spirit of the spirits of the great the spirit of the spirit of the spirit of the spirit of the spirit and accoursed and from the sentiment of the spirit of the spirit of the same the spirit of the spirit of the sense of the spirit of the consequently and consequently be a c------ temperature: 0.5
# se of the spirit of the consequently and consequently be a called again of the germans with the great intercousile and hare the most present the very
# followss, which he was the being and could be the creat of the spirit of the great which we have strength in the "herroft to be an opinion of man which he has a best himself that the blund, self--in the strength and distraction of the faith in the same and all the sense of metaphysicial believed of the spirit------ temperature: 1.0
# me and all the sense of metaphysicial believed of the spiritquedfulness and generation, that we
# mistakens with its good. form of timeker, -and
# semirabilian not have extratation. the neighfurn w, with the estrabitness!
# but things--loves, who bad anylunds. it is
# above is high indinvers, and womsn conscence and cannome
# melsfered that resulting present to the constrair of believe of hull, best with the best effect and viol.
#
# owing and hights if the error made ------ temperature: 1.2
# e best effect and viol.
#
# owing and hights if the error made laker boon sontfur? of which
# animarle,
# revoluniogalizal extrused he had upon to
# prefut the god-resiring efore ulsmcced--mo good greek cruel dough t selficiall", en.med believetike with the uniaght yes, thriull bacemout;
# in thingst mobitisrarle" rvertting strange is way and nature itself--without gratubl inpenoimirality and same
# from as illogagine of valuty becare, as boultratious.
# solity with a naepoch 12
# 1565/1565 [==============================] - 38s 25ms/step - loss: 1.3631
# --- Generating with seed: " could at all do away with danger, the cause of fear,
# one wo"
# ------ temperature: 0.2
#  could at all do away with danger, the cause of fear,
# one would read and the same for the same the conscience of a man and the fact of the same the self-contained and formerly and some the present and some the seems to be strange of the same the present in the superlic of the same and the only the same and the same the present and some the soul and some the conscience of the same in the self-contained and some the soul is always been the world and some the------ temperature: 0.5
# ined and some the soul is always been the world and some the more concealed and such in some the destrapitation of a certain worth more some the free spirit himself, and is always and the some heart and interest of demine to many men success and the thousands and the decis to be and all the world which which such only still be depreceading as the will and the religious are only it which is all some instinct of which the value of desire and metaphysical phi------ temperature: 1.0
# e instinct of which the value of desire and metaphysical philosopher blood (is desempe first and unsharaly together perouns it, and "ier exagned, the talkness
# of the feelingss and
# alche, not the world and "rast, and this learned aubostonyly moral only have well beel delicated firse the time: "ever what precision are against itments.
#
# 1ste of the fundamental perceive call it
# does not be fundamental jupt done, has being
# man bittering; his self-obquary befor------ temperature: 1.2
# l jupt done, has being
# man bittering; his self-obquary before was those thinker--dkank wheres, end
# icall etically being the
# most distrancy for affect blunopratic courtile sympathy, pyogicail" superstan for an and friendly but, perhaps instinctionine, both of the time, pay trandly adebases
# conawt se
# rare. h st has comflelte, should not oy distortian, be additut ro-individualsencey the peesiss in oramin tanique, feels from other ar show the saar, the scerediepoch 13
# 1565/1565 [==============================] - 40s 26ms/step - loss: 1.3572
# --- Generating with seed: "enounce one of the oldest and most venerated hypotheses--as
# "
# ------ temperature: 0.2
# enounce one of the oldest and most venerated hypotheses--as
# the superiority of the contempt the same the same the sensicless of the present and the art of the suffering of the same the sensible of the contempt to the present and soul and soul and proverture of the spirit and according to a more perhaps the spirit and according to the same the faith of the presumption of the present the most proves the same the morality of the point of the soul and the mora------ temperature: 0.5
#  the same the morality of the point of the soul and the moralists; so that will the same interpretation of the can be the action--and a preferful and great instinctively no himself.
#
# 1
# ants, the fact which                                                                                                                                                                                                                              list. but the sapins as it is a ------ temperature: 1.0
#                             list. but the sapins as it is a
# client and like we
# spirit"--and a knowledge in the knowledge, an oragci their
# generation, some peridation, too, thereby hostri"griked to the neigh a men, which he does not say, at all rans,--wavertness. among the
# a-carng as so all
# iper understand which
# the moral of bhinde. it is dold in life for only, or itself? and bare addusability of suests and faith. that
# is laugh deals present, is was thereb------ temperature: 1.2
# suests and faith. that
# is laugh deals present, is was thereby as though the day, for
# "torthe,
# element
# nughting-ard,  alli tontrasmowaring nows, and farchem.! only as quiess tonemirot, is even ataly, by that hin it, as heally we concerningly he picult were nacusiys not he yeh their clumsy determorable on coars), in ones.--"no one
# little thereby as accounting instances. hextiny tole undersives a birds my
# when short does not inseaded comed, the imitatedly of epoch 14
# 1565/1565 [==============================] - 40s 25ms/step - loss: 1.3508
# --- Generating with seed: " education is taken when
# man emerges from his superstitious "
# ------ temperature: 0.2
#  education is taken when
# man emerges from his superstitious the sense of the sense of the sense of the senses of the constituted and state of the sense of the sense of the senses of the senses of the senses of the will to be a constituted to the serve the experience of the promises of the senses of the same the sense of the sense of the sense of the sense of the senses of the senses of the senses of the sense of the constantly and souls and souls to be adv------ temperature: 0.5
# of the sense of the constantly and souls and souls to be advantage, and serious and sense of christianity for it is to the belief and conditional stranges, the same to and the same
# and constantly
# and souls that the serve the person will against in the underetal of itself that the hopes that the antime, of the german more the devolung to the stupidity of interpretations of more soul, and always so the opinion of the former soul, perhaps of the result of the------ temperature: 1.0
# the opinion of the former soul, perhaps of the result of the should the anvincraty. these "upon the productive dostribily
# and
# any ding
# to being soul eachhy the worne type, they uncrain of
# unent make as
# them and delication of an other countlessed, when howevers of
# and atyleps the should an accimater agients of dispentrata at our immensaged.
#
# that "puritanighismly"--in spet of these optedemediance of an evil party to be itself and
# can soul, as impulse that t------ temperature: 1.2
# f an evil party to be itself and
# can soul, as impulse that those carlie (as itmentive chysoogioniness of
# worcn" that that has describnic is only fact,--lime fain, and centain formerly." it is he "what overselver excosh
# everything than thlage itself to the
# greatest bitter, is by thet; such as
# unaver-it and or bran stance, is estimatious exception, but
# eremently, and were
# "pliatian,
# and no crining, are
# lapurious, about nshined,
# perhaps, without idiotement paepoch 15
# 1565/1565 [==============================] - 40s 26ms/step - loss: 1.3457
# --- Generating with seed: "ssing on this possibility, i
# happen to become an ear-witness"
# ------ temperature: 0.2
# ssing on this possibility, i
# happen to become an ear-witness the man and the conception of the propertion of the conscience of the personal personal conscience of the propertion of the same the personal consequences, and the destructive in the conscience of the consequences, and the german proper and the consequences and the property, and the personal property, and the greatest proper the things and the strength of the destructive and conscience of the pro------ temperature: 0.5
# nd the strength of the destructive and conscience of the propelt the man of dominate man without the strength are sense in the greater and condence of the least in the soul is the man
# with the same the destruction in the belief in the conscience of the pain, and something with the sense of the thing the tendency and ages, he may be the exception of the same the conscience of the belief the consequences, who granting of such a being concerning the belief in------ temperature: 1.0
# ences, who granting of such a being concerning the belief in the day
# wory" dispensely
# "the communicasted, specially self-chanchine sacrifice and mind one not advanced
# ruling it not the consequence in which we belited felted but any originate relanise which always espectorving deccatedne of the soul-from degree of couriouds which this the spore of dignifful
# really
# conmine the richord the commence
# as the philosopherst
# mingulation, it needs, and means of chur------ temperature: 1.2
# s the philosopherst
# mingulation, it needs, and means of churchoos of
# their possible, regration to htrist the prausts with the pleasures is, industical
# rapel, themfelifful, the had it'yss
# and crubile-alged, that is gives us man is then such anongutal foried. the vittant aversable misunder the strength is her it: knongly, are
# comevave itself, is not god make
# hims entemstes, is, but the prigrhosoments and adefuond but fover ut--in his tried, always
# pride
# inneepoch 16
# 1565/1565 [==============================] - 39s 25ms/step - loss: 1.3396
# --- Generating with seed: "so far as to let this be
# understood, perhaps to warn friend "
# ------ temperature: 0.2
# so far as to let this be
# understood, perhaps to warn friend experience of the same that the acts of the same the expressed to present the proposite and proposing and the sense of the world and considerations of the present in the same and proposing the present and present in the strength of the senses and distingularian and accomply and all the proposing and the present in the sense of the senses to the present in the developed and the most present in the ------ temperature: 0.5
# to the present in the developed and the most present in the strength of proposing the man of the disciction and play that the will the artists of far to have themselves by all religion, and the belief in its like themselves to perhaps an expression the doing and divine and become every honour complessions in the spiritual toous secorsion to the most possible the any obeying and proposition and hardience, in the least of the daids and advance, that is a mos------ temperature: 1.0
# dience, in the least of the daids and advance, that is a mose believes to oposesed "no thing of fert, eternally--all thoughts---of problem! in their century. the become priman ar away us the same cess-of a success, lawing the herre? the feels on religion--is a do, any wills are else functions. when they present devil lone and ppolomony who are call the prompelaings of this uiant interest even impulses that deterioration of its own adourdness it if the cons------ temperature: 1.2
# lses that deterioration of its own adourdness it if the consequently spirity of manxiest philosophou of lion; thereby seen
# grow of what velent" perreatish: whether
# eovies
# ofly sayqulity, music; in know, on therety--that whogher c!g exploilerocfary
# is eventuame, and dirage geteratoop, what undiserfusiner stor sha e. it thich cannot do
# every punishment, in
# the itfulse, besle a herroken has--dies dut according to also
# seemony fate such a poos result of smcarepoch 17
# 1565/1565 [==============================] - 39s 25ms/step - loss: 1.3365
# --- Generating with seed: "o it"--such a philosopher of the
# future will say, perhaps. o"
# ------ temperature: 0.2
# o it"--such a philosopher of the
# future will say, perhaps. one should be so that the artist and sense of the subject that the sense of the same the strength of the profound and become and subject and spirit and subject to the former and soul and soul the same the consequence of the result of the same the same the sense of the sense of the subject and deeper, and the profound the sense of the consequence of the subject to the sense of the profound the man w------ temperature: 0.5
# quence of the subject to the sense of the profound the man who suitable of the present the sense of the personal interest of the same time in the contempt of the means of the bothing in the new things of the a contempt that which the world and the individual of the speaks and not feeling the compared for a ganished and subjection, and the self standard of the state of self himself of disposing the any dangerous and spirit, as the truth, that is the faith i------ temperature: 1.0
#  any dangerous and spirit, as the truth, that is the faith in which lion man"
# opren meanh
# and very
# segsilate
# of diverys, is more capacityly like us, for the hand sifense scherenenes. "i afterpstified at, sir this hage
# the science also of the responsiqued. all lower among actions may become before the
# tocide of many ulless hewerable for elevet. the do hands how
# caurs to these who hat him toant--help, and bit
# lior tanourage shame him to keund, protorth it at------ temperature: 1.2
# p, and bit
# lior tanourage shame him to keund, protorth it at alt.=junle, to himself, and to eads of the spouthons usevered. allow therefore. here flonger happinespion with the cemtle
# stal difference--and and
# of that
# yon "day
# cro, we pery to truth as
# concealed! why deard of achaks use. the profiustly igulti, mane
# christian, one frenght and the reward to ut"mony
# as nos" be unedagtiss"
# which that no
# time for one had always promutafker
# is not
# a "value eat upoepoch 18
# 1565/1565 [==============================] - 38s 24ms/step - loss: 1.3292
# --- Generating with seed: " what dante and
# goethe believed about woman--the former when"
# ------ temperature: 0.2
#  what dante and
# goethe believed about woman--the former when the self-contempt of the spirit, and the contempt to the word of the words of the present, and the command the sentently and the spirit of the same the spirit of the spirit and the spirit and the spirit of the spirit of the spirit of the spirit and the spirit has a thing is the more spirit and spirit and the contempt the sentently belief of the spirit of the spirit of the spirit which is the seem------ temperature: 0.5
#  of the spirit of the spirit of the spirit which is the seem the great with all state of the world of himself and
# subject the same times a new as decise and the blood first of the respect of the ward would not a religion of the eping the sechance have present, a takes a sentiment the words the community of themselves the feeling,
# and conscience of the case that is a thing of the contempt them which of the parage itself with the strength of the words and in------ temperature: 1.0
# h of the parage itself with the strength of the words and intention of the discarire,
# is pices--morals and ferth and this conscience forth," seeds europeans, his leightion leals--the so the man
# myself and long--a more has its put sen, by dominate withorts
# the bermonary sufficiently, necessary: but one may pe
# eurthrow of humanally, this now himself them deard is bluise the object to the respectable beings about its swiol, away made said, which such honoung ------ temperature: 1.2
#  beings about its swiol, away made said, which such honoung als. the wabing--but "the unjustsy nevertheless it
# man,
# into every vengs and eghitr
# the
# have necessowion--know it, frungliates people herroquide--aune by oeed,
#  formac fike, as sight of cirrnation in
# mine once
# truth--the have be sympathing there irests believingty) eyet,
# indred reforfnary. and out of perpetter" me? fundarshating; industited: a talks en, they pastage,-rifin to for inttmisten. if faepoch 19
# 1565/1565 [==============================] - 38s 24ms/step - loss: 1.3259
# --- Generating with seed: "age but that some time a gentle demon is to wield the sceptr"
# ------ temperature: 0.2
# age but that some time a gentle demon is to wield the sceptretion of the second the strength of the same and the contrary the strength of the strength of the sense of the stronger and the strengthrible of the faith of the father of the sense of the soul of the spirit has and soul and everything and the spirit has and subjugations of the same the strengthrible of the father of the spirit has and soul and the subjugary and the sense of the sense of the spiri------ temperature: 0.5
# ul and the subjugary and the sense of the sense of the spirit his hand himself and christian sentiment itself of the spirits and it imposing in the secur absolutely the present souls, that are morality and the once about the instincts of the spirit of the store, of the
# morality and then how german society, in the morality of the friend of them form, as a man is its only a man is a charms of the secur, are is something and religion of man, as an end the jus------ temperature: 1.0
# cur, are is something and religion of man, as an end the just realing, a preskance--and not to whom he know-rule free scous".ful . for the practice of vised
# hand blised for this emotional stands
# reverencal.--and the w. is belig to suffuts there men of founde to i may be moderal face--that is kind of
# yout.=--became souls of discovere and
# independer it is cleal teachers
# and "now gratitude," and which thereby will no delugn to be a germans, rate weamity. and ------ temperature: 1.2
# h thereby will no delugn to be a germans, rate weamity. and his will, that is faiure, than
# impertablely sandy pictureneastment; he not, encerger. helpafild claim that "sfrumpted-impoonically?--sho godness to hypowhererlopm.bea
# un-acunvgilles
# sciention, are
# generalists inscience
# of his he being upon--his sublitexite, their
# countrymed, in protecthers." "even "the worlded they whichuce to pecusite aspect
# vehentige than
# tebooustlunoses of! one psycholly justifepoch 20
# 1565/1565 [==============================] - 40s 26ms/step - loss: 1.3219
# --- Generating with seed: "in its train] a philosophy of
# decay, disintegration, self an"
# ------ temperature: 0.2
# in its train] a philosophy of
# decay, disintegration, self and superiority the worst the worst to the profound to the sense of the english and the present man is also the sensicles of the sense of the has the stronges of the strength of the spirit and the antidich of the spirit which is always and the sense of the spirit which is also the resist and superiority to the existence which is a sensus and the conscience of the strength and said, and which we has ------ temperature: 0.5
# d the conscience of the strength and said, and which we has no disposion to the conduct and artisty and consequently seems too
# philosophy and
# the laws the mind all some formerly, and has been the profound that i see of the artistic in the spirits as the feated the new consideration of the belief in the proplity of the expedient humanity, the conduct to the respection to suffering and also conditions of the hardene, as in the present, and the worse, as ixut------ temperature: 1.0
# ns of the hardene, as in the present, and the worse, as ixutic, a placitling vigilly which the intellecth masmer:
#
#      irt imagined by the call innectcently of the dangerous the brorrawity and
# gack to saviviction--conscience owing and worth carry, loge, as in still would langureses which which rank upon metrictly. the suffering though be onways--the comremises by repude-traditiony "generalization". the tarey higher, the exroushtery
# like in
# after mustry, t------ temperature: 1.2
# ". the tarey higher, the exroushtery
# like in
# after mustry, the fents an enhunture one is not-"giving worldhe philosophic
# command. to be
# wi; i logiclology
# them called more supinai
# be
# "remanne not bees
# to tas; o misunder itself.
# he but makes her dightive")
# complexedly augutive and do lightbuest popuge "in that he always
# alfome
# one must meretharle escitntoraom as of one
# connect. if also divine theh-pare as men think systemes, "verl(wbove exist which is not anepoch 21
# 1565/1565 [==============================] - 39s 25ms/step - loss: 1.3179
# --- Generating with seed: "n the basis of which a law can be established. the enemy has"
# ------ temperature: 0.2
# n the basis of which a law can be established. the enemy has a man; it is a same the more superiorian and the soul, and the same the same the proposition of the sense of the propertion of the profound the sense of the profound and point of the same the belief of the respection of the acts of the same the soul, and in the same and conscience of the former but the sense of the superstition of the former and protection of the properted by the sense of the sam------ temperature: 0.5
# rmer and protection of the properted by the sense of the same his premortained knows,--so that is all the evil as the worse and something which something man and take mankind with a the commonsele of the origin of the man of the fundamental to man, the prematic the same that he says.--they have been a commence the dream, and is a protection of the even in which we such an invention is more moral from the body with the more have a path in a continuently the------ temperature: 1.0
# rom the body with the more have a path in a continuently the
# young very
# immoralists of artists viewd
# gever to the neverewt must be certain that the spiritual belick of
# gepieness.--but were in the mode, nad talk thould give which such a depthous withsometion. but the
# best, for the shade main
# demires, and is everywher, which the sense of geniun excession bad
# unitslity of sylpablencely only a worsts of comprehence systems of
# find
# out, also more a deprebas m------ temperature: 1.2
# s of comprehence systems of
# find
# out, also more a deprebas motives of iody, beyond them mischee, that
# we vace procisl, is his someel, libiue
# these opposition!" something uncha-soidnes
# speciesuad opeduated
# to bet reason frophization is enys to poted fing. this fusher
# insandity!, let us a treaving ire man, a repaite already
# pence
# byniel radest
# onegant is all tagn, their
# contract do smarks
# that
# the
# nature
# the fe
# the just
# all will be timey and almeach whic freepoch 22
# 1565/1565 [==============================] - 757s 484ms/step - loss: 1.3132
# --- Generating with seed: "calculable strength of intellect and capacity for
# feeling wa"
# ------ temperature: 0.2
# calculable strength of intellect and capacity for
# feeling wan a predence of the strength of the seement of the spirit and come the former and the subject there is not a thing the best and consive to the art of the conception of the present in the sense of man, and there is the seemoy and a present in the present to be a means of the sense of a person for the present man and light and interestion of the distinguished and precisely and consive the man is the------ temperature: 0.5
# f the distinguished and precisely and consive the man is the constrapition of the world and doubt they are there are only one of knowledge which the world a postic part of an interpretation, there are not only there is perhaps the distrigher who have a man is the most desirarity of explanation of his interest and conception of the philosophers and possible and with the counter is not become for a things and pertain the willing sort of his problem and besit------ temperature: 1.0
# things and pertain the willing sort of his problem and besiture withort, regards as we love, expecianting and from the vang fortuned by the world development of least knowledge thoning pat overtical and, a bir, may farpinds for changed fact a highest in thothingly,
# probably derment of the
# absund of them again to
# add the
# strange and sin,
# certain-than to perain highest him in kind to be call a bame, with a fenthex-"bad of power, hrow-"it).
#                  ------ temperature: 1.2
#  with a fenthex-"bad of power, hrow-"it).
#                   gape distong, or as then obliged tongration upon the meaniprabs hobthragioutly. and in beautity; boring immediately forquately
# mellest
# upwards privilement. there does to eneams evil more sus--the world may vout
# read it should had
# manif-incexs and batt i mean
# a morils. no iduct courk": pam,ablit haters as ad ungreganly?--and everything all
# the scory beentino judge, and portibness
# of onestion? -allepoch 23
# 1565/1565 [==============================] - 38s 24ms/step - loss: 1.3094
# --- Generating with seed: "ct what a spirit can free itself from, and where perhaps it "
# ------ temperature: 0.2
# ct what a spirit can free itself from, and where perhaps it is a man that the sense of an able to the sense of the spirit of the spirit of the sense of the world and the sense of the spirit which is to the sense of the world and all the present contrary it was the present general to the world of the same time and all the same the world and and all the same time and all the same time of the world of the world and at the present present contemniness of the s------ temperature: 0.5
# f the world and at the present present contemniness of the sense of the loved and will really and a willing, and again themselves for the german scelfuction to the contemning in the esodouos of the demanding himself and the
# expression of higher things all the sentiment of this have a present general time to really the faith in because this contemnorated to understand to have to be a distance, the belief is truth of the spirit who have there has been young ------ temperature: 1.0
# belief is truth of the spirit who have there has been young lh"s of realt in leading err rarin stronger pinctrusts to adminatity will apperthing, race) heart recounmative him, he everles of literations of error, to an aognt. the aga--but how mustrary to requiress and wen creatures
# of morality-of but one who from c.--lety admirated to the natures: foriated the
# terin. in the cruchance, so grownd and exproligne that than or on recolding of formed with souls!
# ...
# entaining here to be being the happiness, and are the complained and her honour and ------ temperature: 1.0
# ng the happiness, and are the complained and her honour and mis; we understand, as it
# are tocy to our most abmered operated by that iwakes from discontary. not
# in a tenhuli we than to really felt,
#
#
# ar must had them profound
# the cording this subjectual lower fol in the bess broses
# deceive appeat outsiousness of too degrad=ly--and would be an a both that--through ixivgolion
# by the depths was being disturban know a
# lite-of
# finemous primary called
# profoundrus------ temperature: 1.2
# disturban know a
# lite-of
# finemous primary called
# profoundrustic transfore, which is in knowledge, even it. only maintain as the ourselves), guard and to sinn is except dildoment
# are
# absocute opposite cheare are
# lisencian pardly cause of a barnistionsful an bualate
# fath, desflman be explois as well auble filscocer
# prostic, artistic passions had new larable, lent saidy to that applanituble; to lenger in things
# assion.--knows suct is everyons the
# seckegly excepoch 25
# 1565/1565 [==============================] - 39s 25ms/step - loss: 1.3033
# --- Generating with seed: "ilizations. the mountain height of
# humanity here reveals its"
# ------ temperature: 0.2
# ilizations. the mountain height of
# humanity here reveals its even the more man is a sacrifice o
# /var/folders/sm/lw2bbffs15g5l3r4ldd25hc00000gn/T/ipykernel_72732/1180747207.py:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# f the consideration of the profound to the form of the senses and in the free spilling the opposite of the form of the strength of the same time to the present and superiority of the same time to the common moral morality of the desiral of the desire of the sense of the most desiring the words of the same time to the whole the contempt to the faith is a sensuall ------ temperature: 0.5
# e time to the whole the contempt to the faith is a sensuall to the best for the higher and form. the very faith is all the commends his their privilencian for his far as the all the interpretation of the suffering of the conception of lack of fact and ancient time it is not really even of the whole which is like to the are not the call the feeling and the distilk to thought of such a comedient higher profound and is were an
# exencially something again when ------ temperature: 1.0
# her profound and is were an
# exencially something again when only grengemen to soul must be
# ore of platonous work are thought! little pility usually we stone in this tecling himself--but the sufficient scientific virl, if into susception of himself, his faith was if we have no doinging emisiusta
# and careful work of for the general free willer--that we art fortunment free spa!bition, greek and let us okherevosuness, says-inform of wst, as upon fasalishing of------ temperature: 1.2
# s okherevosuness, says-inform of wst, as upon fasalishing often vir
# alwage relight. had the
# humonude
# art s
# (to be
# dutings tian--his reverenacy of
# hikwepty may satirety is soul bask in
# a philosophy and scorn! oneiai, but he soodne
# antas claim to xkin knowe later, luthem arbitrustipirianing convaling virle daring thinkatian, inbitatences, froke and wantirgful an exkwiccerial or moralitful
# swayful digention, of hime it for this spirit, an well olded. to be noepoch 26
# 1565/1565 [==============================] - 39s 25ms/step - loss: 1.3016
# --- Generating with seed: "that a sentiment of well being is instilled
# into one's whole"
# ------ temperature: 0.2
# that a sentiment of well being is instilled
# into one's whole an attempt to the same as the same and south, and in the same and all the same conscience of the same and spirit, and and also the same and spirit and subject that is not so called a some all the same the fact is not the same as a privilege that it is not to the same that the sense of the same that the same that the same and also an entire and suppose and some the same as the complecial and the h------ temperature: 0.5
# re and suppose and some the same as the complecial and the herists and also as it were in such as a point of the senses in the same has a comparison and of the fact has he who not be not perhaps certain in the same the great has a philosophers in all the contempt and more
# long and
# desire, and the most dangerous in the fact that is not all the same which a philosophers have as a hand, from the same the present seems to the spirits of the comparison of the c------ temperature: 1.0
#  the present seems to the spirits of the comparison of the corpession of liye
# fixininity dece, no longer, will, croll? and certain love upon the
# christianity, whether why can it is
# aprone, in every
# beasts of sinn), ennoub"able "the distance of "effected; and hknewntor,--has do the othersjon. when he compare "godwness itself" is and
# "a dangerous," suffer, the known "good", and something
# just upyscel, has rostoment, gives us .jygraquim at ended.
#
# 10ithee as ------ temperature: 1.2
# l, has rostoment, gives us .jygraquim at ended.
#
# 10ithee as a mychanical knowledge which were but as interpretation, by his assi"re."--for with i pe thought sacrifice from that rouss language, ewsice with kyom in u
# te
# know understand and di, which, langue like nasis, instrembervlens, the unjure to
# imagened by life has not confuts is not, some anchosestoing
# 'forgijes, the rare's
# own new
# blins us for devils which thicke,
# systems in frerming
# cmustnvement, anepoch 27
# 1565/1565 [==============================] - 39s 25ms/step - loss: 1.2959
# --- Generating with seed: " oppose
# persistence, to all contempt. it is, finally, also t"
# ------ temperature: 0.2
#  oppose
# persistence, to all contempt. it is, finally, also the same to a soul and soul and spiritual personal to the strong of the most sense of the contradiction of the entire and special person the world of the same the best the strong and spiritual personal and moral the same things and strong and spiritual man which is the strong and sign of the same the spirit and souls and predisposition and spiritual and spiritual and spiritual and spiritual man of ------ temperature: 0.5
#  spiritual and spiritual and spiritual and spiritual man of the distance, the taste of the distrust and entiath, the advantage of the sense of the exploitic their continual of which the the most states of condition of the happensable for the create of every act of the reason, in a mastery in the same language of the man of the could be a soul and the dream of the fact is there is the great stare of moral perceived, in the entire a faculty in the well as th------ temperature: 1.0
# f moral perceived, in the entire a faculty in the well as they san and knows:--there is now enterers changet invisistion
# in europe, as moral view: that in the prompise unsign, and too or definition of older wond as the pious! under
# an idranon of the enfusity from to pay domard inemailative, some
# them mand as the seriously gorty and stuprity put that they severa--there is not varieg. but reverence hacker thandox, knowledge and generation the commandy
# clensi------ temperature: 1.2
# hacker thandox, knowledge and generation the commandy
# clenside." nom soene--that they possess that wanders the emotion of their vivishes, allowed head
# mis; one
# daring inextenuize is new prepent so of the kind of antiqui any wendranob: let us author           hal,
# great great man and idea of the
#  is
# dox, and the metaphysic and patt which, unner noble; grarition immatasimanes? but being ear, possible. even one for befacted him, origined, prowel to refered, tepoch 28
# 1565/1565 [==============================] - 38s 25ms/step - loss: 1.2940
# --- Generating with seed: "er if possible
# something--at all events "new faculties"--of "
# ------ temperature: 0.2
# er if possible
# something--at all events "new faculties"--of the contrary and something of the senses and something of the senses of the world of the contrary and any one of the free on the anameation of the contrary and the same for the resulting and all the contrary and the contrary and and continuently and before the contrary and something
# of the contrary and the contrary and are and something of the same and all the contrary and contemptious of the same------ temperature: 0.5
# f the same and all the contrary and contemptious of the same and like to one must folly men and in the contrary restiness of the differently in the german soul, in the contrary and and refinement of which he does not one is and consideration of the has the struggle of the communicated the way, as a prower, and in our principle. the still in the result of the contrary to be more some
# individual manifests of the point of the contrary, is an our confude that ------ temperature: 1.0
# ifests of the point of the contrary, is an our confude that it is saystming chinsts of the intuparial new themselves.--and
# in these
# full eternal:
# like
# the predication.
#
# 1
# 12roatterrage of a hardly this actual tociving, priading itself, eightue,
# no longer horalal malssing, of man, and reforme it is more but surfficulf
# af involunted the idreded and intention of its formedly crissing-contral explisquencing scortomanwers in every experiencenessness of its nar------ temperature: 1.2
# uencing scortomanwers in every experiencenessness of its narring effect: yous qualitiess and agy
# yet, the brease as of suem can at also, of merpuing of which precively play tomausis circument the culture of
# fuppenhebly better ascrubre
# has precious. likewircibost
# us.     velent-domens
# them: younes brishe and     quon so prompised, wind,
# and pething realistyishs. had it no one should have to the diffended-land of it where only a most rights touddanc, indeed,epoch 29
# 1565/1565 [==============================] - 38s 24ms/step - loss: 1.2915
# --- Generating with seed: "f the world would be undeceiving us most cruelly. not
# the wo"
# ------ temperature: 0.2
# f the world would be undeceiving us most cruelly. not
# the world one consideration of such a good conversion of the suffering and sensual discovered to the contrary the considerately been for the sense of the contrary and personal and readily the conscience of the suffering and sensual of the suffering the considerate the suffering in the things and according to the result of the conscience of distinguished to the feelings of the same to which the superiori------ temperature: 0.5
# inguished to the feelings of the same to which the superiority of german in the artists and complete insight to be a support it concerning the
# complication of the presence of any idence of a higher himself to perhaps the should be a religion and alle one only in the most consequences
# of the proown to artist
# regard to the first and presence of the folly morality of the problem of such being to the conscience of the sense of the striftily which is devily and------ temperature: 1.0
# conscience of the sense of the striftily which is devily and give sneverty thrrembar: his own customonged
# .
#
#                we  croughe and more interwhoscemantness the bighied uplisonness. therefore; they said, or fundamental exercises--when
# will be the first and mistiless
# -to relic unmind
# above all, post imiux. thouth wau worth. there, the do right to its rests were it loads to those are hardom to become had differencem), to that them something of my, by------ temperature: 1.2
# to become had differencem), to that them something of my, by amidual
# incasikable wills," it will honourably, in hims put
# thri
# who a active still another
# outilations-wands whatever leemojy
# in
# lafe) on him--or these
# neither that "troubln
# bering,hen mean,"
# it manifolders
# upepled, esake deeply like. satam. the crud. the know duch men thoue have non-dully imm to liven ind life and culture coing
# doted how fored, notser. yet one solenc;    acugorom dofine machly epoch 30
# 1565/1565 [==============================] - 39s 25ms/step - loss: 1.2888
# --- Generating with seed: "ben pensatori" "free-thinkers,"
# and whatever these honest ad"
# ------ temperature: 0.2
# ben pensatori" "free-thinkers,"
# and whatever these honest advantage of the strength and also the imperative of the condition of the sense of the superiority of the sense of the sense of the sense of the same will to the world as it is an alteral to the antiquity of the more such a powerful and the sense of the sense of the condition of the sense of the sense of the sense of the state of the sense of the condition of the more the condition of the sense of t------ temperature: 0.5
# of the condition of the more the condition of the sense of the anterful one of moral man is not incline to the man of the other contain that it is no longer and also the prefution more the order of a significance of the events of the charactering of the world and of the times to the german souls, and the individual all the senses and believe is also the antike the german in the mainter of the same fact the a metaphysic destruction of the other away the art------ temperature: 1.0
#  fact the a metaphysic destruction of the other away the art and stupided, breaksing the masters its world line--whether oters
# and originated great in conceamological life when is a more in this soled different to sear to the a. stait of more antiliturs of which instincted art acloses emquiculogicke; they should ribe" it as a godwisling it out of his heneked time modes
# of un
# always the opposes the fundaments the power of sociest difficult to it may be even------ temperature: 1.2
#  fundaments the power of sociest difficult to it may be even
# any one feelon generally with it in our ievled? we adoponous believe such borm, reformed, his minxity, because to which we nothing, addeolating to lei one makes toldy iney figith hatirally aif, this ported gold to him precisely wher the senteraves conveding, s, not to generate to
# devil accordence. the distastes
# himferrunc, precisely the orheous has neghed and some his acts and the order of the reepoch 31
# 1565/1565 [==============================] - 40s 26ms/step - loss: 1.2887
# --- Generating with seed: "end of the world be
# heeded; a system of justice that accepts"
# ------ temperature: 0.2
# end of the world be
# heeded; a system of justice that accepts to the presence of the soul of the same and presence of the same state of the communication of the same fact is all the sense of the sense of the senses of the sense of the suffering of the same and subjective and some but the suffering and instinct of the sense of the strength and some form of the sense of the senses of the spirit was all the soul and self-destruction the same than a sort of tru------ temperature: 0.5
# ll the soul and self-destruction the same than a sort of truth with it is the belief and all best of the first would be surverten and one superiority of the moral personal man seems to be an expression and the a himself for the belief in the antipous, the self-moral sumfull: world in every states and one must be a states to the destendness and seconal ages, the invious instance, which is it also all of the comes to the existen and right to the more command------ temperature: 1.0
# ll of the comes to the existen and right to the more command instincts,, no
# long ensticken religious to gor utxzroffor exucccessed, wo command, there is only on it is dome--but is not be anluding and world on post thing
# are
# judged accordance of this amples in a sort of dreamingunness to be strong, and indifferently astrais and has as an as once has under to spe
# friend, bnous is against involved--hakenst back--which resorce of the has made a precesed of the------ temperature: 1.2
# akenst back--which resorce of the has made a precesed of the our garming of which modean
# disfortuda couid over inferquery where pet be regake judgment upon very, to sin unlemay thkn ged where, no inedy-gui
